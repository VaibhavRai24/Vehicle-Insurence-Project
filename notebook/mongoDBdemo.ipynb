# %%
import pandas as pd
import pymongo

df = pd.read_csv('data.csv')  
df.head(10)
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   1    Male   44                1         28.0                   0
# 1   2    Male   76                1          3.0                   0
# 2   3    Male   47                1         28.0                   0
# 3   4    Male   21                1         11.0                   1
# 4   5  Female   29                1         41.0                   1
# 5   6  Female   24                1         33.0                   0
# 6   7    Male   23                1         11.0                   0
# 7   8  Female   56                1         28.0                   0
# 8   9  Female   24                1          3.0                   1
# 9  10  Female   32                1          6.0                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0   > 2 Years            Yes         40454.0                  26.0      217
# ...

# %%
data = df.to_dict(orient='records')

# %%
DB_NAME = "Proj1"
COLLECTION_NAME = "Proj1-data"
CONNECTION_URL = "mongodb+srv://vairaibhav922:lf9WAVOJDQa5OPfI@cluster11.7zk31.mongodb.net/?retryWrites=true&w=majority&appName=Cluster11?"

# %%
import certifi

# %%
client = pymongo.MongoClient(CONNECTION_URL, tls=True, tlsCAFile=certifi.where())
data_base = client[DB_NAME]
collection = data_base[COLLECTION_NAME]

# %%
rec = collection.insert_many(data)
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 rec = collection.insert_many(data)
#
# File c:\Users\VAIBHAVRAI\OneDrive\Desktop\Project 1 MLOPS\vehicleinsurance\Lib\site-packages\pymongo\_csot.py:119, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     117         with _TimeoutContext(timeout):
#     118             return func(self, *args, **kwargs)
# --> 119 return func(self, *args, **kwargs)
#
# File c:\Users\VAIBHAVRAI\OneDrive\Desktop\Project 1 MLOPS\vehicleinsurance\Lib\site-packages\pymongo\synchronous\collection.py:975, in Collection.insert_many(self, documents, ordered, bypass_document_validation, session, comment)
#     973 blk = _Bulk(self, ordered, bypass_document_validation, comment=comment)
#     974 blk.ops = list(gen())
# --> 975 blk.execute(write_concern, session, _Op.INSERT)
# ...
